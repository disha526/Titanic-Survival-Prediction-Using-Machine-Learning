# %% [markdown]
# <a href="https://colab.research.google.com/github/disha526/Titanic-Survival-Prediction-Using-Machine-Learning/blob/main/Wine_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of pandas

# %%
import numpy as n
list =([1,23,3])
array = np.array([1,23,3])
print(array)
print(list)
# Out:
# [ 1 23  3]
# [1, 23, 3]

# %%
array_a = np.array([1,'b', True])
print(array_a)
# Out:
# ['1' 'b' 'True']

# %%
array_b = np.array([1,False])
print(array_b)
# Out:
# [1 0]

# %%
array_c = np.array(([1,2],[2,34]))
array_c
# Out:
# array([[ 1,  2],
#        [ 2, 34]])

# %%
array_c = np.array(([1,2],[2,3]) , ndmin =2 )
array_c
# Out:
# array([[1, 2],
#        [2, 3]])

# %%
list =[1,2,3]
array=np.array([[1,2,3]])
# print(list+1)
print(array+1)
# Out:
# [[2 3 4]]

# %%
import random
rand_array1 = np.random.randint(1,5,3)
print(rand_array1)
# Out:
# [3 2 4]

# %%
rand_array2 = np.random.randn(5) # normal distribution
print(rand_array2)
# Out:
# [ 1.11317978 -0.31260669  1.07394681 -0.88153805 -0.19392376]

# %%
import pandas as pd
s=pd.Series([1,23,34])
s
# Out:
# 0     1
# 1    23
# 2    34
# dtype: int64

# %%
s = pd.Series([1,2,3,4] , index = ["a","b","c","d"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df = pd.DataFrame(["disha","ronith","ramya"] , index =[1,2,3], columns =["names"])
df
# Out:
#     names
# 1   disha
# 2  ronith
# 3   ramya

# %%
df2 ={"Name":"Disha","USN":"4AL23CG010","Age":"20","COURSE":"CSD"}
s_dict = pd.Series(df2)
s_dict
# Out:
# Name           Disha
# USN       4AL23CG010
# Age               20
# COURSE           CSD
# dtype: object

# %%
s_list = pd.Series(["blue","green","yellow","red"])
s_list
# Out:
# 0      blue
# 1     green
# 2    yellow
# 3       red
# dtype: object

# %%
s1_list = pd.Series(["blue","green","yellow","red"],index=['a',"b","c","d"])
s1_list
# Out:
# a      blue
# b     green
# c    yellow
# d       red
# dtype: object

# %%
s2_list =pd.Series(5.0 ,index =[1,2,3,4])
s2_list
# Out:
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# dtype: float64

# %%
data = {"Country":["Belgium","India","Brazil"],
        "Capital":["Brussels","New Delhi","Brasilia"],
        "Population":[111234244,2344444342,5435633]}
df =pd.DataFrame(data,columns=["Country","Capital","Population"])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels   111234244
# 1    India  New Delhi  2344444342
# 2   Brazil   Brasilia     5435633

# %%
data1 = {"a":[1,5],"b":[2,6],"c":[1,2]}
df1 = pd.DataFrame(data1  , columns=["a","b","c"])
df1
# Out:
#    a  b  c
# 0  1  2  1
# 1  5  6  2

# %%
data_2 = {"one":[1.,2.,3.],
          "two":[2,3,4]
          }

df2 = pd.DataFrame(data_2)
df2
# Out:
#    one  two
# 0  1.0    2
# 1  2.0    3
# 2  3.0    4

# %%
data_3 = [{"a":1,"b":3}, {"a":4,"b":3,"c":6}]
df_3 = pd.DataFrame(data_3)
df_3
# Out:
#    a  b    c
# 0  1  3  NaN
# 1  4  3  6.0

# %% [markdown]
# #Wine_Review

# %%
import numpy as np
import pandas as pd

data_set =pd.read_csv("winemag-data-130k-v2.csv")
data_set.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
data_set.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
data_set.shape
# Out:
# (129971, 14)

# %%
data_set.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
type(data_set)
# Out:
# pandas.core.frame.DataFrame
