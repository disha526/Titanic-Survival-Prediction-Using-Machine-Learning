# %% [markdown]
# <a href="https://colab.research.google.com/github/disha526/Titanic-Survival-Prediction-Using-Machine-Learning/blob/main/Pandas_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
arr = [6,-9,7,5,10]
S1 = pd.Series(arr)
S1
# Out:
# 0     6
# 1    -9
# 2     7
# 3     5
# 4    10
# dtype: int64

# %%
order = [1,2,3,4,5]
S2 = pd.Series(arr, index=order)
S2
# Out:
# 1     6
# 2    -9
# 3     7
# 4     5
# 5    10
# dtype: int64

# %%
import numpy as np
n = np .random.randn(5)
index = ['a', 'b', 'c', 'd', 'e']
S2 = pd.Series(n, index=index)
S2
# Out:
# a   -2.358497
# b   -0.995922
# c    2.145149
# d    0.799446
# e    1.263273
# dtype: float64

# %%
d = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
S3 = pd.Series(d)
S3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
S1.index = ['a', 'b', 'c', 'd', 'e']
S1
# Out:
# a     6
# b    -9
# c     7
# d     5
# e    10
# dtype: int64

# %%
S1[:3]    # First three elements
S1[2:-1]  # Slice from index 2 to second to last
S1[-2:]   # Last two elements
# Out:
# d     5
# e    10
# dtype: int64

# %%
S4 = pd.concat([S3])
S4
S4.drop('e')
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
arr1=[1,2,3,4,5]
arr2=[6,7,8,9,10]
S5 = pd.Series(arr2)
S5
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
S6= pd.Series(arr1)
S6
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
S5.add(S6)
S5.sub(S6)
S5.mul(S6)
S5.div(S6)
# Out:
# 0    6.000000
# 1    3.500000
# 2    2.666667
# 3    2.250000
# 4    2.000000
# dtype: float64

# %%
print(S6.median())
print(S6.max())
print(S6.min())
# Out:
# 3.0
# 5
# 1

# %% [markdown]
# #Create dataframe

# %%
dates = pd.date_range('today', periods=6)
num_arr = np.random.randn(6, 4)
cols = ['A', 'B', 'C', 'D']
df1 = pd.DataFrame(num_arr, index=dates, columns=cols)
df1
# Out:
#                                    A         B         C         D
# 2026-03-23 15:59:00.450320  2.359605 -1.151635  0.131331  0.430221
# 2026-03-24 15:59:00.450320 -2.346102  0.329661 -0.474587  0.534318
# 2026-03-25 15:59:00.450320 -1.859141 -0.909454 -0.783292 -0.436260
# 2026-03-26 15:59:00.450320  0.062779 -0.147640 -0.698954  2.572734
# 2026-03-27 15:59:00.450320  1.470825  1.716436  1.725475 -1.076777
# 2026-03-28 15:59:00.450320  0.402744 -0.814168  0.942715  0.784199

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog'],
        'age': [2.5, 3, 0.5, np.nan],
        'visits':[1,3,2,3],
        'priority':['yes','no','yes','yes']}
labels = ['a', 'b', 'c', 'd']
df2 = pd.DataFrame(data, index=labels)
df2
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3       no
# c  snake  0.5       2      yes
# d    dog  NaN       3      yes

# %%
print(df2.dtypes)
print('\n')
print(df2.head(5))
print('\n')
print(df2.tail(3))
print('\n')
print(df2.index )
print('\n')
print(df2.columns)
print('\n')
print(df2.values)
print('\n')
print(df2.describe())
df2.info()
# Out:
# animal       object
# age         float64
# visits        int64
# priority     object
# dtype: object
#
#
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3       no
# c  snake  0.5       2      yes
# d    dog  NaN       3      yes
#
#
#   animal  age  visits priority
# b    cat  3.0       3       no
# c  snake  0.5       2      yes
# d    dog  NaN       3      yes
#
#
# Index(['a', 'b', 'c', 'd'], dtype='object')
#
#
# Index(['animal', 'age', 'visits', 'priority'], dtype='object')
#
#
# [['cat' 2.5 1 'yes']
#  ['cat' 3.0 3 'no']
#  ['snake' 0.5 2 'yes']
#  ['dog' nan 3 'yes']]
#
#
#             age    visits
# count  3.000000  4.000000
# mean   2.000000  2.250000
# std    1.322876  0.957427
# min    0.500000  1.000000
# 25%    1.500000  1.750000
# 50%    2.500000  2.500000
# 75%    2.750000  3.000000
# max    3.000000  3.000000
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 4 columns):
# ...

# %%
df2.T
df2.sort_values(by='age')
# Out:
#   animal  age  visits priority
# c  snake  0.5       2      yes
# a    cat  2.5       1      yes
# b    cat  3.0       3       no
# d    dog  NaN       3      yes

# %%
df2[1:3]
df2[['age', 'visits']]
df2.iloc[1:3]
df3 = df2.copy()
df3.loc['f', 'age'] = 1.5
df3
# Out:
#   animal  age  visits priority
# a    cat  2.5     1.0      yes
# b    cat  3.0     3.0       no
# c  snake  0.5     2.0      yes
# d    dog  NaN     3.0      yes
# f    NaN  1.5     NaN      NaN

# %%
df3['visits'].mean()
# Out:
# np.float64(2.25)

# %%
string = pd.Series(['A','B','C','D','Aaa','BaCa',np.nan,'CBA','cow','owl'])
string.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3       d
# 4     aaa
# 5    baca
# 6     NaN
# 7     cba
# 8     cow
# 9     owl
# dtype: object

# %%
string.str.upper()
# Out:
# 0       A
# 1       B
# 2       C
# 3       D
# 4     AAA
# 5    BACA
# 6     NaN
# 7     CBA
# 8     COW
# 9     OWL
# dtype: object

# %% [markdown]
# #Operations for Dataframe missing value

# %%
df4 = df3.copy()
df4.fillna(4)
# Out:
#   animal  age  visits priority
# a    cat  2.5     1.0      yes
# b    cat  3.0     3.0       no
# c  snake  0.5     2.0      yes
# d    dog  4.0     3.0      yes
# f      4  1.5     4.0        4

# %%
df5 = df3.copy()
df5.dropna(how = 'any')
# Out:
#   animal  age  visits priority
# a    cat  2.5     1.0      yes
# b    cat  3.0     3.0       no
# c  snake  0.5     2.0      yes

# %% [markdown]
# #Dataframe file operation

# %%
df3.to_csv('animal.csv')
df_animal = pd.read_csv('animal.csv')
df_animal
# df_animal.head(3)
# Out:
#   Unnamed: 0 animal  age  visits priority
# 0          a    cat  2.5     1.0      yes
# 1          b    cat  3.0     3.0       no
# 2          c  snake  0.5     2.0      yes
# 3          d    dog  NaN     3.0      yes
# 4          f    NaN  1.5     NaN      NaN

# %%
df3.to_excel('animal.xlsx',sheet_name='Sheet1')
df_animal2= pd.read_excel('animal.xlsx', 'Sheet1', index_col=None,
                          na_values=['NA'])
df_animal2
# Out:
#   Unnamed: 0 animal  age  visits priority
# 0          a    cat  2.5     1.0      yes
# 1          b    cat  3.0     3.0       no
# 2          c  snake  0.5     2.0      yes
# 3          d    dog  NaN     3.0      yes
# 4          f    NaN  1.5     NaN      NaN

# %% [markdown]
# #Visualisation in Pandas

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
ts = pd.Series(np.random.randn(50), index =pd.date_range('today', periods=50))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(50,4), index=ts.index,
                  columns=['A','B','X','Y'])
df = df.cumsum()
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# #Remove repeated data using pandas

# %%
df.loc[df['A'].shift() != df['A']]
# Out:
#                                    A         B         X          Y
# 2026-03-23 15:59:01.430198  0.717465 -0.852934 -1.629339  -1.260868
# 2026-03-24 15:59:01.430198  1.449895  2.114036 -2.545950  -1.864663
# 2026-03-25 15:59:01.430198  1.193805  2.055660 -4.350773  -3.489786
# 2026-03-26 15:59:01.430198  2.720322  2.534315 -4.547043  -3.493470
# 2026-03-27 15:59:01.430198  2.283360  2.023677 -4.580788  -4.516817
# 2026-03-28 15:59:01.430198  1.336117  2.642970 -2.640045  -6.302365
# 2026-03-29 15:59:01.430198 -1.093422  1.712221 -2.893152  -6.566014
# 2026-03-30 15:59:01.430198  1.585697  2.596424 -2.517680  -6.250092
# 2026-03-31 15:59:01.430198  0.972041  1.305683 -2.249440  -7.178288
# 2026-04-01 15:59:01.430198  1.435359 -0.406507 -2.899225  -6.753710
# 2026-04-02 15:59:01.430198 -0.021655 -1.368223 -2.015746  -6.284937
# 2026-04-03 15:59:01.430198 -0.776185 -2.272757 -2.475832  -6.181565
# 2026-04-04 15:59:01.430198 -0.519957 -0.838051 -2.145260  -4.836185
# ...

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5,6,6,7,8]})
df.loc[df['A'].shift(3) != df['A']]
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   6
# 8   6
# 9   7
# 10  8
